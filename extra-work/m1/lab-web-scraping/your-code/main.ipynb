# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended content.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit the urls below and take a look at their source code through Chrome DevTools. You'll need to identify the html tags, special class names, etc used in the html content you are expected to extract.
#
# **Resources**:
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide)
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are already imported for you. If you prefer to use additional libraries feel free to do it.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'  #Como podemos observar todos los nombres de los developers empiezan con el tag "a"

# %%
html = requests.get(url).content

# %%
parsed_html = BeautifulSoup (html,"html.parser")
parsed_html
# Out:
# <!DOCTYPE html>
#
# <html data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# ...

# %%
names = parsed_html.find_all("div", {"class":"Box"})
names
# Out:
# [<div class="Box position-absolute overflow-hidden d-none jump-to-suggestions js-jump-to-suggestions-container">
#  <ul class="d-none js-jump-to-suggestions-template-container">
#  <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-suggestion" role="option">
#  <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="suggestion" href="" tabindex="-1">
#  <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
#  <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# ...

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
name = parsed_html.find_all("div", {"class": "Box"})
name  #aqui tenemos que el tag de los nombres es "div", y las class es "box"
# Out:
# [<div class="Box position-absolute overflow-hidden d-none jump-to-suggestions js-jump-to-suggestions-container">
#  <ul class="d-none js-jump-to-suggestions-template-container">
#  <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-suggestion" role="option">
#  <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" data-item-type="suggestion" href="" tabindex="-1">
#  <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
#  <svg aria-label="Repository" class="octicon octicon-repo js-jump-to-octicon-repo d-none flex-shrink-0" data-view-component="true" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16">
# ...

# %%
#vamos a hacer otra busqueda de los tags y de la class de esos tags de los nombres de los developers.
name2 = parsed_html.find_all("h1", {"class": "h3 lh-condensed"}) #En el caso de los nombres tenemos un tag "h1", y la class de ese tag es "h3 lh-condensed", no solo me va a valer para un nombre ya que todos los nombres de los developers tienen "h1" class="h3 lh-condensed"

name2
#ahora cuando ejecutemos no me van a salir todos los developers pero ya me dice que me da los primeros y el ultimo para no tener que imprimirme todo.
# Out:
# [<h1 class="h3 lh-condensed">
#  <a data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":590471,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="32a919c90023857fa2067b433d0e8edbad393643c2f4827c9e747163efb3d213" data-view-component="true" href="/wagoodman">
#              Alex Goodman
#  </a> </h1>,
#  <h1 class="h3 lh-condensed">
#  <a data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":13172299,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="30ec3e505f8896941b10b2bdb07e58c5fcf061267abfde77accf5f5f7687b676" data-view-component="true" href="/nandorojo">
#              Fernando Rojo
# ...

# %%
#vamos a crear una lista con los nombres de todos los developers, para eso crearemos una lista vacia y despues me hago un for loop sobre name2 que es donde tengo todos los nombres de los developers y los ire añadiendo a la lista vacia con un .append()
#con el metodo .text vamos a coger solamente el texto, pero me pillara el texto con los cambios de linea etc , y nosotros solo queremos pillar los nombres de los developers por lo que nos tenemos que eliminar todos los cambios de linea, por eso hacemos un .strip()
developers = list()
for i in name2:
    
    developers.append((i.text).strip()) #EL METODO .STRIP() ME ELIMINA TODOS LOS CAMBIOS DE LINEA Y SOLO ME PILLARA EL TEXTO DESDE EL PRINCIPIO HASTA EL FINAL, TAMBIEN PODEMOS ESPECIFICARLE QUE ES LO QUE QUEREMOS ELIMINAR DENTRO DE LOS PARENTESIS.
developers
# Out:
# ['Alex Goodman',
#  'Fernando Rojo',
#  'Stephen Celis',
#  'Steve Macenski',
#  'Jacob Ebey',
#  'Avelino',
#  'Jeremy Long',
#  'Robert Mosolgo',
#  'Fernand Galiana',
#  'Shivam Mathur',
#  'Bastian Köcher',
#  'Felix Angelov',
#  'Simon Ser',
#  'Eliza Weisman',
#  'Juliette',
#  'Anton Babenko',
#  'Ben McCann',
#  'Mariusz Nowak',
#  '07akioni',
#  'Jérémy Barbet',
#  'kezhenxu94',
#  'Pedro S. Lopez',
#  'Adrian Wälchli',
#  'Jonny Borges',
#  'Karol Wrótniak']

# %%
name3 = parsed_html.find_all("a", {"class": "Link--secondary"})
name3
# Out:
# [<a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Why GitHub?","action":"click to go to Mobile","label":"ref_page:/trending/developers;ref_cta:Mobile;"}' data-hydro-click='{"event_type":"analytics.event","payload":{"category":"Header dropdown (logged out), Why GitHub?","action":"click to go to Mobile","label":"ref_page:/trending/developers;ref_cta:Mobile;","originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="e179cc6283e532c4e400f567659c2787140f3a20a366f335ff7f468531f2dc55" href="/mobile">
#        Mobile
#  </a>,
# ...

# %%
users= list()
for i in name3:
    users.append((i.text).strip())
users
# Out:
# ['Mobile',
#  'Actions',
#  'Codespaces',
#  'Packages',
#  'Security',
#  'Code review',
#  'Issues',
#  'Integrations',
#  'Topics',
#  'Collections',
#  'Trending',
#  'Learning Lab',
#  'Open source guides',
#  'The ReadME Project',
#  'Events',
#  'Community forum',
#  'GitHub Education',
#  'GitHub Stars program',
#  'Compare plans',
#  'Contact Sales',
#  'wagoodman',
#  'nandorojo',
#  'stephencelis',
#  'SteveMacenski',
#  'jacob-ebey',
#  'avelino',
#  'jeremylong',
#  'rmosolgo',
#  'derailed',
#  'shivammathur',
#  'bkchr',
#  'felangel',
#  'emersion',
#  'hawkw',
#  'jrfnl',
#  'antonbabenko',
#  'benmccann',
#  'medikoo',
#  '07akioni',
#  'jeremybarbet',
#  'kezhenxu94',
#  'pedroslopez',
#  'awaelchli',
#  'jonataslaw',
#  'koral--']

# %% [markdown]
# #### Display the trending Python repositories in GitHub.
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url2 = 'https://github.com/trending/python?since=daily'

# %%
html2 = requests.get(url2).content

# %%
parsed_html2 = BeautifulSoup (html2,"html.parser")
print(type(parsed_html2))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
name2_ = parsed_html2.find_all("h1", {"class": "h3 lh-condensed"})
name2_
# Out:
# [<h1 class="h3 lh-condensed">
#  <a data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_REPOSITORIES_PAGE","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":437139341,"originating_url":"https://github.com/trending/python?since=daily","user_id":null}}' data-hydro-click-hmac="33d857439a92f98e7dcecbc9bff6461113d0f01c512f2d354f1983dd29fc0857" data-view-component="true" href="/kozmer/log4j-shell-poc">
#  <svg aria-hidden="true" class="octicon octicon-repo mr-1 color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# ...

# %%
repos_name = list()
for i in name2_ :
    
    
    repos_name.append((i.text).strip()) #EL METODO .STRIP() ME ELIMINA TODOS LOS CAMBIOS DE LINEA Y SOLO ME PILLARA EL TEXTO DESDE EL PRINCIPIO HASTA EL FINAL, TAMBIEN PODEMOS ESPECIFICARLE QUE ES LO QUE QUEREMOS ELIMINAR DENTRO DE LOS PARENTESIS.
repos_name #AQUI NO ME ESTA LLENANDO LA LISTA CON NADA
# Out:
# ['kozmer /\n\n      log4j-shell-poc',
#  'ytdl-org /\n\n      youtube-dl',
#  'NCSC-NL /\n\n      log4shell',
#  'fullhunt /\n\n      log4j-scan',
#  'fox-it /\n\n      log4j-finder',
#  'minitorch /\n\n      minitorch',
#  'psf /\n\n      black',
#  'cyberstruggle /\n\n      L4sh',
#  'kakaobrain /\n\n      minDALL-E',
#  'jackfrued /\n\n      Python-100-Days',
#  'iterativv /\n\n      NostalgiaForInfinity',
#  'tiangolo /\n\n      fastapi',
#  'zabbix /\n\n      community-templates',
#  'facebookresearch /\n\n      moco',
#  'sanic-org /\n\n      sanic',
#  'tqdm /\n\n      tqdm',
#  'PrefectHQ /\n\n      prefect',
#  'willmcgugan /\n\n      rich',
#  'MalwareTech /\n\n      Log4jTools',
#  'PaddlePaddle /\n\n      PaddleClas',
#  'niubiqigai /\n\n      turtle',
#  'kubernetes-client /\n\n      python',
#  'nccgroup /\n\n      ScoutSuite',
#  'altair-viz /\n\n      altair',
#  'CLUEbenchmark /\n\n      CLUE']

# %%
repos_name = pd.DataFrame(repos_name)
repos_name
# Out:
#                                             0
# 0           kozmer /\n\n      log4j-shell-poc
# 1              ytdl-org /\n\n      youtube-dl
# 2                NCSC-NL /\n\n      log4shell
# 3              fullhunt /\n\n      log4j-scan
# 4              fox-it /\n\n      log4j-finder
# 5              minitorch /\n\n      minitorch
# 6                        psf /\n\n      black
# 7               cyberstruggle /\n\n      L4sh
# 8             kakaobrain /\n\n      minDALL-E
# 9        jackfrued /\n\n      Python-100-Days
# 10  iterativv /\n\n      NostalgiaForInfinity
# 11                tiangolo /\n\n      fastapi
# 12      zabbix /\n\n      community-templates
# 13           facebookresearch /\n\n      moco
# 14                 sanic-org /\n\n      sanic
# 15                       tqdm /\n\n      tqdm
# 16               PrefectHQ /\n\n      prefect
# 17                willmcgugan /\n\n      rich
# 18          MalwareTech /\n\n      Log4jTools
# ...

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page.

# %%
# This is the url you will scrape in this exercise
url3 = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
html3 = requests.get(url3).content

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page.

# %%
# This is the url you will scrape in this exercise
url4 ='https://en.wikipedia.org/wiki/Python'

# %%
html4= requests.get(url4).content

# %%
parsed_html4 = BeautifulSoup (html4,"html.parser")
print(type(parsed_html4))
# Out:
# <class 'bs4.BeautifulSoup'>

# %% [markdown]
# #### Find the number of titles that have changed in the United States Code since its last release point.

# %%
# This is the url you will scrape in this exercise
url5= 'http://uscode.house.gov/download/download.shtml'

# %%
html5= requests.get(url5).content
parsed_html5 = BeautifulSoup (html5,"html.parser")
print(type(parsed_html5))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
titles_changed = parsed_html5.find_all("div", {"class":"usctitle"})
titles_changed
# Out:
# [<div class="usctitle" id="alltitles">
#
#            All titles in the format selected compressed into a zip archive.
#
#          </div>,
#  <div class="usctitle" id="heading">
#
#
#
#  	        </div>,
#  <div class="usctitle" id="us/usc/t1">
#
#            Title 1 - General Provisions <span class="footnote"><a class="fn" href="#fn">٭</a></span>
#  </div>,
#  <div class="usctitle" id="us/usc/t3">
#
#            Title 3 - The President <span class="footnote"><a class="fn" href="#fn">٭</a></span>
#  </div>,
#  <div class="usctitle" id="us/usc/t4">
#
#            Title 4 - Flag and Seal, Seat of Government, and the States <span class="footnote"><a class="fn" href="#fn">٭</a></span>
#  </div>,
#  <div class="usctitle" id="us/usc/t5">
#
#            Title 5 - Government Organization and Employees <span class="footnote"><a class="fn" href="#fn">٭</a></span>
#  </div>,
#  <div class="usctitle" id="us/usc/t6">
#
#            Title 6 - Domestic Security
#
#          </div>,
# ...

# %%
titulos_cambiados = list()

for i in titles_changed:

    titulos_cambiados.append((i.text))

titulos_cambiados
# Out:
# <div class="usctitle" id="alltitles">
#
#           All titles in the format selected compressed into a zip archive.
#
#         </div>
# <class 'bs4.element.Tag'>
# <div class="usctitle" id="heading">
#
#
#
# 	        </div>
# <class 'bs4.element.Tag'>
# <div class="usctitle" id="us/usc/t1">
#
#           Title 1 - General Provisions <span class="footnote"><a class="fn" href="#fn">٭</a></span>
# </div>
# <class 'bs4.element.Tag'>
# <div class="usctitle" id="us/usc/t3">
#
#           Title 3 - The President <span class="footnote"><a class="fn" href="#fn">٭</a></span>
# </div>
# <class 'bs4.element.Tag'>
# <div class="usctitle" id="us/usc/t4">
#
#           Title 4 - Flag and Seal, Seat of Government, and the States <span class="footnote"><a class="fn" href="#fn">٭</a></span>
# </div>
# <class 'bs4.element.Tag'>
# <div class="usctitle" id="us/usc/t5">
#
#           Title 5 - Government Organization and Employees <span class="footnote"><a class="fn" href="#fn">٭</a></span>
# </div>
# ...

# %% [markdown]
# #### Find a Python list with the top ten FBI's Most Wanted names.

# %%
# This is the url you will scrape in this exercise
url6 = 'https://www.fbi.gov/wanted/topten'

# %%
html6= requests.get(url6).content
parsed_html6 = BeautifulSoup (html6,"html.parser")
print(type(parsed_html6))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
most_wanted= parsed_html6.find_all("h3", {"class": "title"})
most_wanted
print(type(most_wanted))
# Out:
# <class 'bs4.element.ResultSet'>

# %%
mas_buscados = list()

for i in most_wanted:
   
    mas_buscados.append((i.text).strip())
mas_buscados
# Out:
# ['ALEXIS FLORES',
#  'JOSE RODOLFO VILLARREAL-HERNANDEZ',
#  'OCTAVIANO JUAREZ-CORRO',
#  'RAFAEL CARO-QUINTERO',
#  'YULAN ADONAY ARCHAGA CARIAS',
#  'EUGENE PALMER',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'ALEJANDRO ROSALES CASTILLO',
#  'ARNOLDO JIMENEZ',
#  'JASON DEREK BROWN']

# %% [markdown]
# ####  Display the 20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url7 = 'https://www.emsc-csem.org/Earthquake/'

# %%
html7= requests.get(url7).content
parsed_html7 = BeautifulSoup (html7,"html.parser")
print(type(parsed_html7))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
latest_earthquakes =  parsed_html7.find_all("td", {"class": "tabev6"})
latest_earthquakes
# Out:
# [<td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1077794">2021-12-16   10:02:00.7</a></b><i class="ago" id="ago0">14min ago</i></td>,
#  <td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1077793">2021-12-16   10:01:36.7</a></b><i class="ago" id="ago1">14min ago</i></td>,
#  <td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1077785">2021-12-16   10:00:29.1</a></b><i class="ago" id="ago2">15min ago</i></td>,
#  <td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1077791">2021-12-16   09:57:31.3</a></b><i class="ago" id="ago3">18min ago</i></td>,
#  <td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1077786">2021-12-16   09:53:27.0</a></b><i class="ago" id="ago4">22min ago</i></td>,
# ...

# %%
fechas = list()

for i in latest_earthquakes:
    
    filas = i.text
    
    filas = list()
    filas.append(i.text[10:20])
    
    fechas.append(filas.append(i.text[10:20]))

# %% [markdown]
# #### Count the number of tweets by a given Twitter account.
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url8 = 'https://twitter.com/'

# %%
html8= requests.get(url8).content

parsed_html8 = BeautifulSoup (html8,"html.parser")
print(type(parsed_html8))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
latest_earthquakes =  parsed_html8.find_all("td", {"class": "tabev6"})
latest_earthquakes
# Out:
# []

# %% [markdown]
# #### Number of followers of a given twitter account
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the followers for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url9 = 'https://twitter.com/'

# %%
html9= requests.get(url9).content
parsed_html9 = BeautifulSoup (html9,"html.parser")
print(type(parsed_html9))
# Out:
# <class 'bs4.BeautifulSoup'>

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org.

# %%
# This is the url you will scrape in this exercise
url10 = 'https://www.wikipedia.org/'

# %%
html10= requests.get(url10).content
parsed_html10 = BeautifulSoup (html10,"html.parser")
print(type(parsed_html10))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
languaje_names  =  parsed_html10.find_all("a", {"class": "link-box"})
languaje_names
# Out:
# [<a class="link-box" data-slogan="The Free Encyclopedia" href="//en.wikipedia.org/" id="js-link-box-en" title="English — Wikipedia — The Free Encyclopedia">
#  <strong>English</strong>
#  <small><bdi dir="ltr">6 383 000+</bdi> <span>articles</span></small>
#  </a>,
#  <a class="link-box" data-slogan="フリー百科事典" href="//ja.wikipedia.org/" id="js-link-box-ja" title="Nihongo — ウィキペディア — フリー百科事典">
#  <strong>日本語</strong>
#  <small><bdi dir="ltr">1 292 000+</bdi> <span>記事</span></small>
#  </a>,
#  <a class="link-box" data-slogan="Свободная энциклопедия" href="//ru.wikipedia.org/" id="js-link-box-ru" title="Russkiy — Википедия — Свободная энциклопедия">
#  <strong>Русский</strong>
#  <small><bdi dir="ltr">1 756 000+</bdi> <span>статей</span></small>
#  </a>,
#  <a class="link-box" data-slogan="Die freie Enzyklopädie" href="//de.wikipedia.org/" id="js-link-box-de" title="Deutsch — Wikipedia — Die freie Enzyklopädie">
#  <strong>Deutsch</strong>
# ...

# %%
lista_lenguajes = list()
for i in languaje_names:
   
    lista_lenguajes.append((i.text))
lista_lenguajes    

#AHORA TENGO QUE LIMPIAR LA LISTA lista_lenguajes CON REGEX. SUSTITUYENDO LOS CARACTERES QUE NO QUERAMOS POR NADA.
# Out:
# ['\nEnglish\n6\xa0383\xa0000+ articles\n',
#  '\n日本語\n1\xa0292\xa0000+ 記事\n',
#  '\nРусский\n1\xa0756\xa0000+ статей\n',
#  '\nDeutsch\n2\xa0617\xa0000+ Artikel\n',
#  '\nEspañol\n1\xa0717\xa0000+ artículos\n',
#  '\nFrançais\n2\xa0362\xa0000+ articles\n',
#  '\n中文\n1\xa0231\xa0000+ 條目\n',
#  '\nItaliano\n1\xa0718\xa0000+ voci\n',
#  '\nPortuguês\n1\xa0074\xa0000+ artigos\n',
#  '\nPolski\n1\xa0490\xa0000+ haseł\n']

# %%
#### A list with the different kind of datasets available in data.gov.uk.

# %%
# This is the url you will scrape in this exercise
url11 = 'https://data.gov.uk/'

# %%
html11= requests.get(url11).content
parsed_html11 = BeautifulSoup (html11,"html.parser")
print(type(parsed_html11))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
open_datasets  =  parsed_html11.find_all("a", {"class": "govuk-link"})
open_datasets


datasets = list()
for i in open_datasets:
   
    datasets.append((i.text))
    


datasets = datasets[4:]
datasets
# Out:
# ['Business and economy',
#  'Crime and justice',
#  'Defence',
#  'Education',
#  'Environment',
#  'Government',
#  'Government spending',
#  'Health',
#  'Mapping',
#  'Society',
#  'Towns and cities',
#  'Transport',
#  'Digital service performance',
#  'Government reference data']

# %% [markdown]
# #### Display the top 10 languages by number of native speakers stored in a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url12 = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
html12= requests.get(url12).content
parsed_html12 = BeautifulSoup (html12,"html.parser")
print(type(parsed_html12))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
top_languages  =  parsed_html12.find_all("a", {"class": "wikitable sortable jquery-tablesorter"})
top_languages
# Out:
# []

# %% [markdown]
# ## Bonus
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### Display IMDB's top 250 data (movie name, initial release, director name and stars) as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code here

# %% [markdown]
# #### Display the movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
# your code here

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = input('Enter the city: ')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code here

# %% [markdown]
# #### Find the book name, price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
# your code here
